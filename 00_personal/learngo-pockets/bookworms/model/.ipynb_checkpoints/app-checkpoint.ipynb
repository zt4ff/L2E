# %% [markdown]
# ### Steps to take
#
# 1. prepare data and clean data
# 2. select model, fit model and config hyperparameters
# 3. deploy model
# 4. OPTIONAL - if deployed model can be turned to a function for Go

# %%
import json
import pandas as pd

# %%
try:
    with open("bookworms_dataset.json", "r") as file:
        data = json.load(file)
except FileNotFoundError:
    print("Error file not found")
except json.JSONDecodeError:
    print("Error decoding json")

books = pd.DataFrame(data["books"])
users = pd.DataFrame(data["bookworms"])

users
# Out:
#    user_id     name  age                                           location  \
# 0     u001     Fadi   29  {'city': 'Beirut', 'country': 'Lebanon', 'time...
# 1     u002    Peggy   34  {'city': 'Dublin', 'country': 'Ireland', 'time...
# 2     u003    Amara   26  {'city': 'Lagos', 'country': 'Nigeria', 'timez...
# 3     u004    Soren   41  {'city': 'Copenhagen', 'country': 'Denmark', '...
# 4     u005     Lena   31  {'city': 'Berlin', 'country': 'Germany', 'time...
# 5     u006    Tomás   38  {'city': 'Buenos Aires', 'country': 'Argentina...
# 6     u007     Yuki   27  {'city': 'Tokyo', 'country': 'Japan', 'timezon...
# 7     u008    Priya   33  {'city': 'Mumbai', 'country': 'India', 'timezo...
# 8     u009    Kwame   45  {'city': 'Accra', 'country': 'Ghana', 'timezon...
# 9     u010    Clara   22  {'city': 'Lisbon', 'country': 'Portugal', 'tim...
# 10    u011  Dimitri   50  {'city': 'Athens', 'country': 'Greece', 'timez...
# ...

# %%
from pandas import json_normalize

users_full = json_normalize(data["bookworms"])
users_full.head(3)
# Out:
#   user_id   name  age member_since  \
# 0    u001   Fadi   29   2021-03-15
# 1    u002  Peggy   34   2020-07-01
# 2    u003  Amara   26   2022-01-20
#
#                                           books_read  \
# 0  [{'book_id': 'b001', 'rating': 5, 'date_read':...
# 1  [{'book_id': 'b002', 'rating': 4, 'date_read':...
# 2  [{'book_id': 'b023', 'rating': 5, 'date_read':...
#
#                                             wishlist location.city  \
# 0  [{'book_id': 'b014', 'added_date': '2022-06-01...        Beirut
# 1  [{'book_id': 'b012', 'added_date': '2022-03-01...        Dublin
# 2  [{'book_id': 'b047', 'added_date': '2022-10-01...         Lagos
#
#   location.country location.timezone      preferences.favorite_genres  ...  \
# 0          Lebanon       Asia/Beirut    [dystopia, feminist, fiction]  ...
# 1          Ireland     Europe/Dublin     [classic, romance, dystopia]  ...
# 2          Nigeria      Africa/Lagos  [fiction, historical, feminist]  ...
#
# ...

# %%
rows = []

for user in data["bookworms"]:
    for br in user["books_read"]:
        rows.append({
            "user_id": user["user_id"],
            "book_id": br["book_id"],
            "rating": br["rating"],
            "did_not_finish": br["did_not_finish"],
            "reread": br["reread"]
        })

interactions = pd.DataFrame(rows)

interactions
# Out:
#    user_id book_id  rating  did_not_finish  reread
# 0     u001    b001       5           False   False
# 1     u001    b003       4           False   False
# 2     u002    b002       4           False   False
# 3     u002    b001       5           False    True
# 4     u002    b004       5           False    True
# ..     ...     ...     ...             ...     ...
# 73    u015    b050       4           False   False
# 74    u015    b005       4           False   False
# 75    u015    b009       5           False   False
# 76    u015    b006       3           False   False
# 77    u015    b040       3           False   False
#
# [78 rows x 5 columns]

# %%
df = interactions.merge(books, on="book_id", how="left")

df
# Out:
#    user_id book_id  rating  did_not_finish  reread                 title  \
# 0     u001    b001       5           False   False   The Handmaid's Tale
# 1     u001    b003       4           False   False          The Bell Jar
# 2     u002    b002       4           False   False        Oryx and Crake
# 3     u002    b001       5           False    True   The Handmaid's Tale
# 4     u002    b004       5           False    True             Jane Eyre
# ..     ...     ...     ...             ...     ...                   ...
# 73    u015    b050       4           False   False  The Name of the Rose
# 74    u015    b005       4           False   False                  1984
# 75    u015    b009       5           False   False              The Road
# 76    u015    b006       3           False   False       Brave New World
# 77    u015    b040       3           False   False        Fahrenheit 451
#
#               author author_id                             genres  year  \
# ...

# %%
user_prefs = {
    u["user_id"]: u["preferences"]["favorite_genres"]
    for u in data["bookworms"]
}

user_prefs
# Out:
# {'u001': ['dystopia', 'feminist', 'fiction'],
#  'u002': ['classic', 'romance', 'dystopia'],
#  'u003': ['fiction', 'historical', 'feminist'],
#  'u004': ['sci-fi', 'dystopia', 'classic'],
#  'u005': ['fiction', 'drama', 'mental-health'],
#  'u006': ['thriller', 'crime', 'fiction'],
#  'u007': ['fiction', 'sci-fi', 'contemporary'],
#  'u008': ['classic', 'romance', 'coming-of-age'],
#  'u009': ['historical', 'fiction', 'drama'],
#  'u010': ['contemporary', 'romance', 'fiction'],
#  'u011': ['classic', 'historical', 'fiction'],
#  'u012': ['sci-fi', 'feminist', 'fiction'],
#  'u013': ['historical', 'drama', 'coming-of-age'],
#  'u014': ['fiction', 'feminist', 'contemporary'],
#  'u015': ['crime', 'thriller', 'fiction']}

# %%
def genre_overlap(user_id, book_genres):
    user_genres = set(user_prefs[user_id])
    book_genres = set(book_genres)
    return len(user_genres & book_genres) / len(user_genres | book_genres)

df["genre_overlap"] = df.apply(
    lambda x: genre_overlap(x["user_id"], x["genres"]),
    axis=1
)

df
# Out:
#    user_id book_id  rating  did_not_finish  reread                 title  \
# 0     u001    b001       5           False   False   The Handmaid's Tale
# 1     u001    b003       4           False   False          The Bell Jar
# 2     u002    b002       4           False   False        Oryx and Crake
# 3     u002    b001       5           False    True   The Handmaid's Tale
# 4     u002    b004       5           False    True             Jane Eyre
# ..     ...     ...     ...             ...     ...                   ...
# 73    u015    b050       4           False   False  The Name of the Rose
# 74    u015    b005       4           False   False                  1984
# 75    u015    b009       5           False   False              The Road
# 76    u015    b006       3           False   False       Brave New World
# 77    u015    b040       3           False   False        Fahrenheit 451
#
#               author author_id                             genres  year  \
# ...

# %%
user_authors = {}

for user in data["bookworms"]:
    read_authors = []
    for br in user["books_read"]:
        book = books[books["book_id"] == br["book_id"]].iloc[0]
        read_authors.append(book["author_id"])
    user_authors[user["user_id"]] = set(read_authors)

df["author_affinity"] = df.apply(
    lambda x: 1 if x["author_id"] in user_authors[x["user_id"]] else 0,
    axis=1
)

# %%
user_avg = interactions.groupby("user_id")["rating"].mean()

df["user_avg_rating"] = df["user_id"].map(user_avg)
df["rating_delta"] = df["user_avg_rating"] - df["avg_rating"]

# %%
df["reread"] = df["reread"].astype(int)
df["did_not_finish"] = df["did_not_finish"].astype(int)

# %%
feature_cols = [
    "genre_overlap",
    "author_affinity",
    "rating_delta",
    "reread",
    "did_not_finish",
    "pages",
    "year"
]

X = df[feature_cols]
y = df["rating"]

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.8718581553839163
